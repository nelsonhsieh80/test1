# %%
#list 的typehint
rabbits:list[str]=["Flopsy","Mopsy","Cottontail","Peter"] #只有建立的時候要

for rabbit in rabbits:
    print(rabbit)
# Out:
# Flopsy
# Mopsy
# Cottontail
# Peter

# %%
#list 的typehint
rabbits=["Flopsy","Mopsy","Cottontail","Peter"] #只有建立的時候要

for rabbit in rabbits:
    print(rabbit)
# Out:
# Flopsy
# Mopsy
# Cottontail
# Peter

# %%
#第二種資料結構 dict 也叫做map資料  已是iterable 用大括號， 和list差異是 他是用key代表(對應)字串
#比如說 tw 對應taiwanabs{"tw":"Taiwan", ....}

country_code:dict[str,str] = {"tw":"Taiwan", "jp": "Japan", "hk":"Hong Kong", "kr": "Korea"}
for code in country_code:
    print(f"key:{code}")
    print(f"value:{country_code[code]}")
    print("=============")

# %%
#輸入英文字母(按q離開)
while True: 
    stuff=input("請輸入小寫英文字[按q離開]:")
    if stuff=="q":
        break
    print(stuff.capitalize())
print("程式結束")
